# %% [markdown]
# # EU Tenders - Sample Notebook

# %% [markdown]
# ## Explore data

# %%
import pandas as pd        

# Read csv file
dataframe = pd.read_csv("./data/02-silver/eu-tenders-public-transport/eu-tenders-public-transport-DEG.csv")

# %%
# Display 5 first rows
dataframe.head()
# Out:
#    Unnamed: 0  ...                           award-criterion-type-lot
# 0           0  ...                                          ['price']
# 1           1  ...  ['price', 'price', 'price', 'price', 'price', ...
# 2           2  ...  ['price', 'price', 'price', 'price', 'price', ...
# 3           3  ...                                                NaN
# 4           4  ...  ['price', 'price', 'price', 'price', 'price', ...
#
# [5 rows x 25 columns]

# %%
# Display dataframe info
dataframe.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           46 non-null     int64
#  1   notice-type                          46 non-null     str
#  2   place-of-performance                 46 non-null     str
#  3   procedure-type                       46 non-null     str
#  4   publication-date                     46 non-null     str
#  5   publication-number                   46 non-null     str
#  6   buyer-name                           46 non-null     str
#  7   title-proc                           45 non-null     str
#  8   additional-info-proc                 32 non-null     str
#  9   document-url-lot                     37 non-null     str
#  10  option-description-lot               7 non-null      str
#  11  description-lot                      45 non-null     str
# ...

# %%
# Describe dataframe
dataframe.describe()
# Out:
#        Unnamed: 0   total-value
# count   46.000000  8.000000e+00
# mean    22.500000  4.547929e+07
# std     13.422618  8.088572e+07
# min      0.000000  1.000000e-02
# 25%     11.250000  3.258701e+05
# 50%     22.500000  1.440117e+06
# 75%     33.750000  4.969147e+07
# max     45.000000  1.764706e+08
