# %% [markdown]
# # EU Tenders - Sample Notebook

# %% [markdown]
# ## Explore data

# %%
import pandas as pd        

# Read csv file
dataframe = pd.read_csv("./data/02-silver/eu-tenders-public-transport/eu-tenders-public-transport-DEG.csv")

# %%
# Display 5 first rows
dataframe.head()
# Out:
#     notice-type  ...                                         notice-url
# 0  can-standard  ...  https://ted.europa.eu/de/notice/-/detail/21221...
# 1  can-standard  ...  https://ted.europa.eu/de/notice/-/detail/19226...
# 2  can-standard  ...  https://ted.europa.eu/de/notice/-/detail/17880...
# 3      pin-tran  ...  https://ted.europa.eu/de/notice/-/detail/89539...
# 4   cn-standard  ...  https://ted.europa.eu/de/notice/-/detail/86386...
#
# [5 rows x 25 columns]

# %%
# Display dataframe info
dataframe.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   notice-type                          46 non-null     str
#  1   place-of-performance                 46 non-null     str
#  2   procedure-type                       46 non-null     str
#  3   publication-date                     46 non-null     str
#  4   publication-number                   46 non-null     str
#  5   buyer-name                           46 non-null     str
#  6   title-proc                           45 non-null     str
#  7   additional-info-proc                 32 non-null     str
#  8   document-url-lot                     37 non-null     str
#  9   option-description-lot               7 non-null      str
#  10  description-lot                      45 non-null     str
#  11  description-proc                     45 non-null     str
#  12  contract-duration-start-date-lot     44 non-null     str
#  13  contract-duration-end-date-lot       41 non-null     str
#  14  winner-name                          1 non-null      str
#  15  main-classification-proc             45 non-null     float64
#  16  direct-award-justification-proc      3 non-null      str
#  17  selection-criterion-description-lot  33 non-null     str
#  18  organisation-contact-point-buyer     24 non-null     str
#  19  organisation-tel-buyer               45 non-null     str
#  20  organisation-email-buyer             45 non-null     str
#  21  renewal-maximum-lot                  6 non-null      float64
#  22  total-value                          8 non-null      float64
#  23  award-criterion-type-lot             32 non-null     str
#  24  notice-url                           46 non-null     str
# dtypes: float64(3), str(22)
# memory usage: 1.5 MB

# %%
# Describe dataframe
dataframe.describe()
# Out:
#        main-classification-proc  renewal-maximum-lot   total-value
# count              4.500000e+01             6.000000  8.000000e+00
# mean               6.082861e+07             2.166667  4.547929e+07
# std                4.548694e+06             0.752773  8.088572e+07
# min                6.000000e+07             1.000000  1.000000e-02
# 25%                6.000000e+07             2.000000  3.258701e+05
# 50%                6.011200e+07             2.000000  1.440117e+06
# 75%                6.013000e+07             2.750000  4.969147e+07
# max                9.051350e+07             3.000000  1.764706e+08
